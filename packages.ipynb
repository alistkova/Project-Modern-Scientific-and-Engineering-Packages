# %%
import pandas as pd
import schedule_statistics

# %% [markdown]
# ### Прочитаем данные, которые будем обрабатывать

# %%
data = pd.read_json('results.json', encoding='utf-8')

# %%
data.head()
# Out:
#                                                Title  \
# 0  Расписание преподавателя: Алипов Алексей Серге...
# 1  Расписание преподавателя: Алпатов Геннадий Евг...
# 2  Расписание преподавателя: Остапчук-Петровская ...
# 3  Расписание преподавателя: Алтунян Армен Грантович
# 4  Расписание преподавателя: Анохина Елена Михайл...
#
#          EducatorDisplayText              EducatorLongDisplayText  \
# 0               Алипов А. С.             Алипов Алексей Сергеевич
# 1              Алпатов Г. Е.          Алпатов Геннадий Евгеньевич
# 2  Остапчук-Петровская Л. Б.  Остапчук-Петровская Лиана Борисовна
# 3              Алтунян А. Г.              Алтунян Армен Грантович
# 4              Анохина Е. М.             Анохина Елена Михайловна
#
#               DateRangeDisplayText  EducatorMasterId  IsSpringTerm  \
# 0  1 февраля 2024 - 1 августа 2024              1003          True
# 1  1 февраля 2024 - 1 августа 2024              1005          True
# ...

# %% [markdown]
# ### Посмотрим на статистики

# %%
tasks = [
  schedule_statistics.task1,
  schedule_statistics.task2,
  schedule_statistics.task3,
  schedule_statistics.task4,
  schedule_statistics.task5,
  schedule_statistics.task6,
  schedule_statistics.task7,
  schedule_statistics.task8,
  schedule_statistics.task9,
  schedule_statistics.task10,
  schedule_statistics.task11,
  schedule_statistics.task12,
  schedule_statistics.task13,
]

statistics = {i: None for i in range(1, 14)}

# %%
statistics[1] = tasks[0](data)
statistics[1].to_excel(f'task{1}.xlsx', index=False)
statistics[1]
# Out:
#    Количество преподавателей, у которых есть пары
# 0                                            4795

# %%
statistics[2] = tasks[1](data)
statistics[2].to_excel(f'task{2}.xlsx', index=False)
statistics[2]
# Out:
#                     Name            Value
# 0           Алипов А. С.  [11, 35, 21.33]
# 1          Алпатов Г. Е.     [0, 4, 0.67]
# 2          Алтунян А. Г.   [6, 17, 11.67]
# 3          Анохина Е. М.    [2, 26, 13.0]
# 4         Асочаков Ю. В.    [0, 10, 2.33]
# ...                  ...              ...
# 4716  Некрестьянов Д. С.      [0, 3, 1.0]
# 4717      Чернятин В. Ю.     [0, 1, 0.33]
# 4718      Рубанова М. П.     [0, 3, 1.17]
# 4719      Шевченко И. И.     [0, 5, 1.17]
# 4720         Ващук А. Э.   [13, 24, 19.0]
#
# [4721 rows x 2 columns]

# %%
statistics[3] = tasks[2](data)
statistics[3].to_excel(f'task{3}.xlsx', index=False)
statistics[3]
# Out:
#                Name  Value
# 0  Покровская Н. В.  71.33
# 1       Жугра А. В.   0.17

# %% [markdown]
# ![dinozavr](./pokrovskaya.jpg)
# ![dinozavr](./zugra.jpg)
# ![dinozavr](./minmax.jpg)

# %%
statistics[4] = tasks[3](data)
statistics[4].to_excel(f'task{4}.xlsx', index=False)
statistics[4]
# Out:
#            Day  Value
# 0  Понедельник  26325
# 1      Вторник  25552
# 2        Среда  23129
# 3      Четверг  23158
# 4      Пятница  20796
# 5      Суббота  15548

# %%
statistics[5] = tasks[4](data)
statistics[5].to_excel(f'task{5}.xlsx', index=False)
statistics[5]
# Out:
#    Отменили
# 0         0

# %% [markdown]
# ![dinozavr](./meme.jpg)

# %%
statistics[6] = tasks[5](data)
statistics[6].to_excel(f'task{6}.xlsx', index=False)
statistics[6]
# Out:
#            Time  Value
# 0   11:40-13:10   2045
# 1   17:10-18:45   2143
# 2   13:00-14:30   2271
# 3   15:40-17:10   2291
# 4   14:20-15:50   2755
# 5   12:40-14:10   2815
# 6    9:00-10:30   2904
# 7   10:40-12:10   3028
# 8   17:00-18:30   3221
# 9   17:20-18:50   3362
# 10  16:00-17:30   3623
# 11  14:00-15:30   3787
# 12  10:00-11:30   7113

# %%
statistics[7] = tasks[6](data)
statistics[7].to_excel(f'task{7}.xlsx', index=False)
statistics[7]
# Out:
#                                                 Name  Value
# 0  Русский язык для иностранных граждан, практиче...    727
# 1              Английский язык, практическое занятие    864
# 2  Производственная практика (научно-исследовател...    901

# %%
statistics[8] = tasks[7](data)
statistics[8].to_excel(f'task{8}.xlsx', index=False)
statistics[8]
# Out:
#                                                Place  Value
# 0          Большой проспект В.О., д. 71, лит. А, 305   1475
# 1  С использованием информационно-коммуникационны...  14052

# %% [markdown]
# ![dinozavr](./cab.jpg)
# ![dinozavr](./447.jpg)
# ![dinozavr](./225.jpg)

# %%
statistics[9] = tasks[8](data)
statistics[9].to_excel(f'task{9}.xlsx', index=False)
statistics[9]
# Out:
#    Всего групп
# 0         1943

# %%
statistics[10] = tasks[9](data)
statistics[10].to_excel(f'task{10}.xlsx', index=False)
statistics[10]
# Out:
#                                                  Name  Value
# 0                               инженер-исследователь     25
# 1   председатель государственной экзаменационной к...     27
# 2                           младший научный сотрудник     29
# 3                           ведущий научный сотрудник     29
# 4                                   научный сотрудник     51
# 5                           старший научный сотрудник     79
# 6                                           ассистент    444
# 7                                       преподаватель    854
# 8                               старший преподаватель    878
# 9                                           профессор    881
# 10                                             доцент   1474

# %%
statistics[11] = tasks[10](data)
statistics[11].to_excel(f'task{11}.xlsx', index=False)
statistics[11]
# Out:
#                                                     Name  Value
# 0      Основы исследования операций и теории игр, лекция      1
# 1      Основы исследования операций и теории игр, пра...      1
# 2      Электив. Основы моделирования в экономике, пра...      1
# 3      Современная экономическая политика России, лекция      1
# 4      Современная экономическая политика России, сем...      1
# ...                                                  ...    ...
# 10318  Национальные интересы стран БРИКС в контексте ...      5
# 10319  Электив. Английский язык в сфере профессиональ...      6
# 10320  Электив. Учебная (ознакомительная) практика: о...     10
# 10321  Электив. Учебная (ознакомительная) практика: о...     23
# 10322  Электив. Подготовка к выполнению НИР: проверка...     35
#
# [10323 rows x 2 columns]

# %%
statistics[12] = tasks[11](data)
statistics[12].to_excel(f'task{12}.xlsx', index=False)
statistics[12]
# Out:
#      Name  Value
# 0  1 курс  47064
# 1  2 курс  36848
# 2  3 курс  21520
# 3  4 курс  23664
# 4  5 курс   2259
# 5  6 курс   1610

# %%
statistics[13] = tasks[12](data)
statistics[13].to_excel(f'task{13}.xlsx', index=False)
statistics[13]
# Out:
#                                                   Name  Value
# 0                   16-я линия В.О., д. 29, лит. A,110      1
# 1                   6-я линия В.О., д. 15, лит. A, 307      1
# 2                      14 линия В.О., д. 39, Помещение      1
# 3                  21-я линия В.О., д. 8a, лит. А, 215     17
# 4                    6-я линия В.О., д. 11, лит. Д, 21     18
# ..                                                 ...    ...
# 693       Университетский проспект, д. 35, лит. Б, 316     70
# 694      Ульяновская улица, д. 3, корп. Г, лит. А, 211     95
# 695       Университетский проспект, д. 28, лит. Б,1141      9
# 696  Университетский проспект, д. 35, корп. Б, лит....     67
# 697      Университетский проспект, д. 35, лит. А, 2003     13
#
# [698 rows x 2 columns]

# %% [markdown]
# ![dinozavr](./vo.jpg)
# ![dinozavr](./peterhof.jpg)
